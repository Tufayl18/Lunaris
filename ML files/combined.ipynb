# %%
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pylab as plt
import torch
import matplotlib.pyplot as plt1

# %%
model_type = "MiDaS_small"
midas = torch.hub.load('intel-isl/MiDaS', model_type)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
midas.to(device)
midas.eval()

# Input transformation pipeline
transforms = torch.hub.load('intel-isl/MiDaS', 'transforms')
if model_type == "DPT_Large" or model_type == "DPT_Hybrid":
    transform = transforms.dpt_transform
else:
    transform = transforms.small_transform
# Out:
# Using cache found in /Users/bigfatrat/.cache/torch/hub/intel-isl_MiDaS_master
# Loading weights:  None
# Using cache found in /Users/bigfatrat/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# Using cache found in /Users/bigfatrat/.cache/torch/hub/intel-isl_MiDaS_master

# %%
def find_largest_max_depth_area(depth_map):
    THRESHOLD = 100
    max_depth = np.max(depth_map)
    print("MAX DEPTH: ", max_depth)
    
    # binary mask (0,1)
    mask = depth_map >= max_depth - THRESHOLD
    mask = mask.astype(np.uint8)
    
    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # key=cv2.contourArea -> identifies the largest connected region 
    largest_contour = max(contours, key=cv2.contourArea) 
    
    # Get bounding box and centroid
    x, y, w, h = cv2.boundingRect(largest_contour)
    centroid_x = x + w // 2
    centroid_y = y + h // 2
    
    return max_depth, (centroid_x, centroid_y), contours



def visualize_largest_max_depth_area(depth_map, rgb_image):
    max_depth, centroid, contours = find_largest_max_depth_area(depth_map)
    
    for contour in contours:
        cv2.polylines(img, [contour], True, color=(0, 255, 0), thickness=2)
        # centroid
        cv2.circle(rgb_image, (centroid[0], centroid[1]), 5, (0, 255, 0), -1)
    
    return rgb_image

# %%
model = YOLO('../Crater-Detector/best.pt')
class_names = model.names

# %%
import os

cap = cv2.VideoCapture('../asset-check/video.mp4')

output_dir = 'output_images'

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
          
    # Process frame for both predictions (depth and object detection)
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    imgbatch = transform(img).to(device)

    with torch.no_grad():
        depth_prediction = midas(imgbatch)
        depth_prediction = torch.nn.functional.interpolate(
            depth_prediction.unsqueeze(1), size=img.shape[:2], mode='bicubic', align_corners=False
        ).squeeze()
        depth_output = depth_prediction.cpu().numpy()


    # Normalize depth values to 0-255 for visualization
    output = (depth_output - depth_output.min()) / (depth_output.max() - depth_output.min()) * 255
    output = output.astype(np.uint8)
    output = cv2.applyColorMap(output, cv2.COLORMAP_WINTER)
    cv2.imshow('Depth Map', output)
    
    output_filename = os.path.join(output_dir, f'depth_frame.jpg')
    cv2.imwrite(output_filename, output)
    
    image_with_depth = visualize_largest_max_depth_area(depth_output, img)
    

    results = model.predict(img.copy())  

    for r in results:
        boxes = r.boxes
        masks = r.masks

        if masks is not None:
            masks = masks.data.cpu()
            
            for seg, box in zip(masks.data.cpu().numpy(), boxes):
                seg = cv2.resize(seg, (img.shape[1], img.shape[0])) 
                contours, _ = cv2.findContours((seg).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
                # print(sorted_contours)
                for i, contour in enumerate(sorted_contours):
                    M = cv2.moments(contour)
                    if M["m00"] == 0:
                        continue
                    cX = int(M["m10"] / M["m00"])
                    cY = int(M["m01"] / M["m00"])
                    
                    d = int(box.cls)
                    c = class_names[d]
                    x, y, x1, y1 = cv2.boundingRect(contour)

                    depth_at_center = depth_output[cY, cX]  # Get depth at object center
                    cv2.putText(img, "Est.:{}".format(str(round(depth_at_center, 2))), (x, y - 10), cv2.FONT_HERSHEY_PLAIN, 1, (255, 255, 255), 1)

                    cv2.polylines(img, [contour], True, color=(0, 0, 255), thickness=1)
                    cv2.putText(img, str(i) + c, (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    cv2.circle(img, (cX, cY), 5, (0, 0, 255), -1)

                    ratio_pixel_mm = 155 / 14 # 14 mm = 155 pixels
                    mm = x1 / ratio_pixel_mm
                    cm = mm / 10
                    cv2.putText(img, str(round(cm, 2)), (x, y-30), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 255), 1)
                    
                    rect = cv2.minAreaRect(contour)
                    (mx,my),(mw,mh),angle = rect
                    cv2.putText(img, "Angle:{}".format(angle), (int(x), int(y)-40), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 1 )
                    cv2.putText(img, "Area:{}".format(cv2.contourArea(contour)), (int(x), int(y)), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 1 )

    # Display results
    cv2.imshow('Combined Prediction', img)

    output_filename = os.path.join(output_dir, f'output_frame.jpg')
    cv2.imwrite(output_filename, img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# MAX DEPTH:  999.40405
#
# 0: 384x640 6 craters, 153.3ms
# Speed: 14.0ms preprocess, 153.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  979.26904
#
# 0: 384x640 8 craters, 547.4ms
# Speed: 1.4ms preprocess, 547.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  961.0736
#
# 0: 384x640 6 craters, 111.7ms
# Speed: 1.2ms preprocess, 111.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  992.68304
#
# 0: 384x640 7 craters, 108.9ms
# Speed: 1.1ms preprocess, 108.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  952.0862
#
# 0: 384x640 5 craters, 216.2ms
# Speed: 2.7ms preprocess, 216.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  940.3625
#
# 0: 384x640 5 craters, 141.6ms
# Speed: 1.3ms preprocess, 141.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  931.43024
#
# 0: 384x640 6 craters, 227.2ms
# Speed: 1.1ms preprocess, 227.2ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  934.0545
#
# 0: 384x640 6 craters, 348.1ms
# Speed: 3.6ms preprocess, 348.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  930.50385
#
# 0: 384x640 4 craters, 158.0ms
# Speed: 4.9ms preprocess, 158.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  949.31934
#
# 0: 384x640 4 craters, 197.1ms
# Speed: 2.1ms preprocess, 197.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  934.13666
#
# 0: 384x640 6 craters, 286.8ms
# Speed: 1.4ms preprocess, 286.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  964.0822
#
# 0: 384x640 6 craters, 215.8ms
# Speed: 27.3ms preprocess, 215.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  906.1638
#
# 0: 384x640 6 craters, 131.0ms
# Speed: 1.3ms preprocess, 131.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  880.7009
#
# 0: 384x640 3 craters, 136.4ms
# Speed: 1.4ms preprocess, 136.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  894.0818
#
# 0: 384x640 6 craters, 168.1ms
# Speed: 4.0ms preprocess, 168.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  884.77734
#
# 0: 384x640 7 craters, 187.3ms
# Speed: 1.1ms preprocess, 187.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  925.18286
#
# 0: 384x640 9 craters, 143.9ms
# Speed: 1.3ms preprocess, 143.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  925.7988
#
# 0: 384x640 6 craters, 147.9ms
# Speed: 1.1ms preprocess, 147.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  956.7187
#
# 0: 384x640 8 craters, 117.8ms
# Speed: 1.1ms preprocess, 117.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  917.9166
#
# 0: 384x640 7 craters, 126.7ms
# Speed: 1.0ms preprocess, 126.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  965.555
#
# 0: 384x640 9 craters, 162.9ms
# Speed: 1.1ms preprocess, 162.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:
4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  912.48065
#
# 0: 384x640 3 craters, 129.9ms
# Speed: 1.3ms preprocess, 129.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  913.4233
#
# 0: 384x640 3 craters, 148.2ms
# Speed: 1.1ms preprocess, 148.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  922.7528
#
# 0: 384x640 3 craters, 124.4ms
# Speed: 1.3ms preprocess, 124.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  896.51685
#
# 0: 384x640 3 craters, 122.8ms
# Speed: 1.1ms preprocess, 122.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  895.7325
#
# 0: 384x640 2 craters, 150.7ms
# Speed: 1.3ms preprocess, 150.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  908.85315
#
# 0: 384x640 1 crater, 172.3ms
# Speed: 1.4ms preprocess, 172.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  890.17
#
# 0: 384x640 2 craters, 187.7ms
# Speed: 2.0ms preprocess, 187.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  858.8472
#
# 0: 384x640 4 craters, 145.6ms
# Speed: 1.3ms preprocess, 145.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  871.7364
#
# 0: 384x640 6 craters, 257.3ms
# Speed: 5.4ms preprocess, 257.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  865.6958
#
# 0: 384x640 3 craters, 127.9ms
# Speed: 1.1ms preprocess, 127.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  901.5909
#
# 0: 384x640 3 craters, 248.9ms
# Speed: 1.4ms preprocess, 248.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  928.29834
#
# 0: 384x640 1 crater, 135.4ms
# Speed: 1.7ms preprocess, 135.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  905.1994
#
# 0: 384x640 3 craters, 116.1ms
# Speed: 1.3ms preprocess, 116.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  880.858
#
# 0: 384x640 2 craters, 132.0ms
# Speed: 1.2ms preprocess, 132.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  895.9049
#
# 0: 384x640 2 craters, 122.2ms
# Speed: 1.2ms preprocess, 122.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  906.05237
#
# 0: 384x640 2 craters, 121.0ms
# Speed: 1.2ms preprocess, 121.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  895.925
#
# 0: 384x640 2 craters, 123.7ms
# Speed: 1.3ms preprocess, 123.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  872.7966
#
# 0: 384x640 1 crater, 117.5ms
# Speed: 1.2ms preprocess, 117.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  875.2351
#
# 0: 384x640 2 craters, 275.0ms
# Speed: 1.3ms preprocess, 275.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  943.4093
#
# 0: 384x640 3 craters, 118.8ms
# Speed: 1.2ms preprocess, 118.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  916.1292
#
# 0: 384x640 4 craters, 174.5ms
# Speed: 1.3ms preprocess, 174.5ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 640)
# MAX DEPTH:  970.2631
#
# 0: 384x640 4 craters, 567.1ms
# Speed: 1.2ms preprocess, 567.1ms inference, 69.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# M[i,j] ->  Σ ( Σ (x^i)(y^j)I(x,y) ) where I is binary mask matrix and x is row y is col

# M["m00"] = sum of (sum of row) -> no. of 1s present in the moment

# M["m10"] = row1 + row2 + row3 ... where,
# 1st row = 1 x (sum of elements)
# 2nd row = 2 x (sum of elements)
# 3rd row = 3 x (sum of elements)

# M["m01"] = col1 + col2 + col3 ... where,
# 1st col = 1 x (sum of elements)
# 2nd col = 2 x (sum of elements)
# 3rd col = 3 x (sum of elements)

# M["m11"] = row1 + row2 + row3 ... where,
# 1st row = (1)(1)(value) + (1)(2)(value) + (1)(3)(value) ...
# 2nd row = (2)(1)(value) + (2)(2)(value) + (2)(3)(value) ...
# 3rd row = (3)(1)(value) + (3)(2)(value) + (3)(3)(value) ...
