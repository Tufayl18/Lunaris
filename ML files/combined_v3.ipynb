# %%
from flask import Flask, Response, stream_with_context
import cv2
import requests
import numpy as np
from ultralytics import YOLO
import pandas as pd
from glob import glob
import matplotlib.pylab as plt
import torch

app = Flask(__name__)

# %%
model_type = "MiDaS_small"
midas = torch.hub.load('intel-isl/MiDaS', model_type)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
midas.to(device)
midas.eval()

# Input transformation pipeline
transforms = torch.hub.load('intel-isl/MiDaS', 'transforms')
if model_type == "DPT_Large" or model_type == "DPT_Hybrid":
    transform = transforms.dpt_transform
else:
    transform = transforms.small_transform
# Out:
# Using cache found in /Users/bigfatrat/.cache/torch/hub/intel-isl_MiDaS_master
# Loading weights:  None
# Using cache found in /Users/bigfatrat/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# Using cache found in /Users/bigfatrat/.cache/torch/hub/intel-isl_MiDaS_master

# %%
def find_largest_max_depth_area(depth_map):
    THRESHOLD = 100
    max_depth = np.max(depth_map)
    print("MAX DEPTH: ", max_depth)
    # Send the max depth value back to the Raspberry Pi server
    max_depth_op = float(max_depth)
    requests.post("http://192.168.107.54:5000/processing_done", json={"message": f"Max Depth is {max_depth_op}."})
    
    # binary mask (0,1)
    mask = depth_map >= max_depth - THRESHOLD
    mask = mask.astype(np.uint8)
    
    # Find contours
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # key=cv2.contourArea -> identifies the largest connected region 
    largest_contour = max(contours, key=cv2.contourArea) 
    
    # Get bounding box and centroid
    x, y, w, h = cv2.boundingRect(largest_contour)
    centroid_x = x + w // 2
    centroid_y = y + h // 2
    
    return max_depth, (centroid_x, centroid_y), contours



def visualize_largest_max_depth_area(depth_map, rgb_image):
    max_depth, centroid, contours = find_largest_max_depth_area(depth_map)
    
    for contour in contours:
        cv2.polylines(rgb_image, [contour], True, color=(0, 255, 0), thickness=2)
        # centroid
        cv2.circle(rgb_image, (centroid[0], centroid[1]), 5, (0, 255, 0), -1)
    
    return rgb_image

# %%
model = YOLO('../Crater-Detector/best.pt')
class_names = model.names

# %%
# URL to receive the video feed from Raspberry Pi
RPI_VIDEO_URL = "http://192.168.107.54:5000/video_feed"  # Replace with actual Raspberry Pi IP

# %%
def process_frame(frame):
    # Process frame for both predictions (depth and object detection)
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    imgbatch = transform(img).to(device)

    with torch.no_grad():
        depth_prediction = midas(imgbatch)
        depth_prediction = torch.nn.functional.interpolate(
            depth_prediction.unsqueeze(1), size=img.shape[:2], mode='bicubic', align_corners=False
        ).squeeze()
        depth_output = depth_prediction.cpu().numpy()


    # Normalize depth values to 0-255 for visualization
    output = (depth_output - depth_output.min()) / (depth_output.max() - depth_output.min()) * 255
    output = output.astype(np.uint8)
    output = cv2.applyColorMap(output, cv2.COLORMAP_WINTER)
    # cv2.imshow('Depth Map', output)
    
    # output_filename = os.path.join(output_dir, f'depth_frame.jpg')
    # cv2.imwrite(output_filename, output)
    
    image_with_depth = visualize_largest_max_depth_area(depth_output, img)
    
    results = model.predict(img.copy())  

    depth_at_center = 0
    angle = 0
    area = 0

    for r in results:
        boxes = r.boxes
        masks = r.masks

        if masks is not None:
            masks = masks.data.cpu()
            
            for seg, box in zip(masks.data.cpu().numpy(), boxes):
                seg = cv2.resize(seg, (img.shape[1], img.shape[0])) 
                contours, _ = cv2.findContours((seg).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)
                # print(sorted_contours)
                for i, contour in enumerate(sorted_contours):
                    M = cv2.moments(contour)
                    if M["m00"] == 0:
                        continue
                    cX = int(M["m10"] / M["m00"])
                    cY = int(M["m01"] / M["m00"])
                    
                    d = int(box.cls)
                    c = class_names[d]
                    x, y, x1, y1 = cv2.boundingRect(contour)

                    depth_at_center = depth_output[cY, cX]  # Get depth at object center
                    cv2.putText(img, "Est.:{}".format(str(round(depth_at_center, 2))), (x, y - 10), cv2.FONT_HERSHEY_PLAIN, 1, (255, 255, 255), 1)

                    cv2.polylines(img, [contour], True, color=(0, 0, 255), thickness=1)
                    cv2.putText(img, str(i) + c, (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
                    cv2.circle(img, (cX, cY), 5, (0, 0, 255), -1)

                    ratio_pixel_mm = 155 / 14 # 14 mm = 155 pixels
                    mm = x1 / ratio_pixel_mm
                    cm = mm / 10
                    cv2.putText(img, str(round(cm, 2)), (x, y-30), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 255), 1)
                    
                    rect = cv2.minAreaRect(contour)
                    (mx,my),(mw,mh),angle = rect
                    cv2.putText(img, "Angle:{}".format(angle), (int(x), int(y)-40), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 1 )
                    cv2.putText(img, "Area:{}".format(cv2.contourArea(contour)), (int(x), int(y)), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 1 )
                    area = float(cv2.contourArea(contour))

    # Display results
    # cv2.imshow('Combined Prediction', img)
    processed_frame = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

    # output_filename = os.path.join(output_dir, f'output_frame.jpg')
    # cv2.imwrite(output_filename, img)            
    
    # Send the max depth value back to the Raspberry Pi server
    depth_at_center = float(depth_at_center)
    angle = float(angle)
    
    requests.post("http://192.168.107.54:5000/processing_done", json={"message": f"Est depth at center is {depth_at_center}, Angle is {angle}, Area is {area}"})
    
    return processed_frame

# %%
# import time 

def generate_processed_frames():
    stream = requests.get(RPI_VIDEO_URL, stream=True)
    byte_buffer = b''
    for chunk in stream.iter_content(chunk_size=1024):
        byte_buffer += chunk

        a = byte_buffer.find(b'\xff\xd8')  # Start of JPEG
        b = byte_buffer.find(b'\xff\xd9')  # End of JPEG

        if a != -1 and b != -1:
            jpg = byte_buffer[a:b+2]
            byte_buffer = byte_buffer[b+2:]

            # Decode frame and process
            frame = cv2.imdecode(np.frombuffer(jpg, dtype=np.uint8), cv2.IMREAD_COLOR)
            processed_frame = process_frame(frame)

            # Send confirmation message back to Raspberry Pi after processing
            requests.post("http://192.168.107.54:5000/processing_done", json={"message": "Processing done for this frame"})

            # Encode the processed frame back to JPEG
            ret, buffer = cv2.imencode('.jpg', processed_frame)
            if not ret:
                continue

            processed_frame = buffer.tobytes()

            # time.sleep(2)

            # Yield the processed frame as bytes
            yield (b'--frame\r\n'
                   b'Content-Type: image/jpeg\r\n\r\n' + processed_frame + b'\r\n')

# %%
@app.route('/')
def index():
    # Automatically redirect to /processed_feed
    return Response("Redirecting to /processed_feed", status=302, headers={'Location': '/processed_feed'})

@app.route('/processed_feed')
def processed_feed():
    return Response(stream_with_context(generate_processed_frames()), mimetype='multipart/x-mixed-replace; boundary=frame')

# %%
app.run(host='0.0.0.0', port=5001)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://192.168.107.172:5001
# Press CTRL+C to quit
# 192.168.107.172 - - [25/Oct/2024 15:36:49] "GET / HTTP/1.1" 302 -
# MAX DEPTH:  839.0211
#
# 0: 480x640 5 Boulders, 4 craters, 179.8ms
# Speed: 1.5ms preprocess, 179.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 192.168.107.172 - - [25/Oct/2024 15:36:50] "GET /processed_feed HTTP/1.1" 200 -
# MAX DEPTH:  803.971
#
# 0: 480x640 1 Boulder, 5 craters, 239.7ms
# Speed: 1.0ms preprocess, 239.7ms inference, 16.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  844.79755
#
# 0: 480x640 4 Boulders, 5 craters, 144.2ms
# Speed: 1.1ms preprocess, 144.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  868.0027
#
# 0: 480x640 2 Boulders, 6 craters, 151.9ms
# Speed: 1.4ms preprocess, 151.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  869.86755
#
# 0: 480x640 2 Boulders, 6 craters, 144.3ms
# Speed: 1.1ms preprocess, 144.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  837.4005
#
# 0: 480x640 1 Boulder, 3 craters, 145.0ms
# Speed: 1.0ms preprocess, 145.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  894.78894
#
# 0: 480x640 5 Boulders, 4 craters, 142.4ms
# Speed: 1.3ms preprocess, 142.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  876.6879
#
# 0: 480x640 5 Boulders, 6 craters, 134.9ms
# Speed: 1.0ms preprocess, 134.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  962.4214
#
# 0: 480x640 5 Boulders, 3 craters, 142.9ms
# Speed: 1.1ms preprocess, 142.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1079.0383
#
# 0: 480x640 5 Boulders, 3 craters, 130.3ms
# Speed: 0.9ms preprocess, 130.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  932.09106
#
# 0: 480x640 4 Boulders, 3 craters, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  992.18146
#
# 0: 480x640 5 Boulders, 3 craters, 135.4ms
# Speed: 1.0ms preprocess, 135.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  981.3559
#
# 0: 480x640 6 Boulders, 3 craters, 132.3ms
# Speed: 0.9ms preprocess, 132.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  999.5166
#
# 0: 480x640 5 Boulders, 2 craters, 164.5ms
# Speed: 1.3ms preprocess, 164.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  902.1318
#
# 0: 480x640 4 Boulders, 5 craters, 139.5ms
# Speed: 1.8ms preprocess, 139.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  979.57086
#
# 0: 480x640 4 Boulders, 2 craters, 138.9ms
# Speed: 1.1ms preprocess, 138.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  917.8072
#
# 0: 480x640 5 Boulders, 2 craters, 134.1ms
# Speed: 1.1ms preprocess, 134.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  946.3864
#
# 0: 480x640 5 Boulders, 4 craters, 131.7ms
# Speed: 1.0ms preprocess, 131.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1061.9603
#
# 0: 480x640 5 Boulders, 2 craters, 255.0ms
# Speed: 1.1ms preprocess, 255.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1024.6658
#
# 0: 480x640 4 Boulders, 3 craters, 147.9ms
# Speed: 0.9ms preprocess, 147.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1019.5157
#
# 0: 480x640 6 Boulders, 3 craters, 139.4ms
# Speed: 0.9ms preprocess, 139.4ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1069.095
#
# 0: 480x640 5 Boulders, 2 craters, 135.5ms
# Speed: 1.0ms preprocess, 135.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1025.5239
#
# 0: 480x640 4 Boulders, 2 craters, 139.0ms
# Speed: 1.4ms preprocess, 139.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1134.1154
#
# 0: 480x640 4 Boulders, 2 craters, 140.4ms
# Speed: 1.1ms preprocess, 140.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1090.053
#
# 0: 480x640 5 Boulders, 3 craters, 143.3ms
# Speed: 1.0ms preprocess, 143.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  983.6118
#
# 0: 480x640 5 Boulders, 4 craters, 150.4ms
# Speed: 1.5ms preprocess, 150.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1044.7256
#
# 0: 480x640 7 Boulders, 3 craters, 145.0ms
# Speed: 0.9ms preprocess, 145.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1025.5806
#
# 0: 480x640 6 Boulders, 2 craters, 132.0ms
# Speed: 0.9ms preprocess, 132.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  937.39056
#
# 0: 480x640 4 Boulders, 2 craters, 136.5ms
# Speed: 1.0ms preprocess, 136.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  875.3853
#
# 0: 480x640 5 Boulders, 2 craters, 126.3ms
# Speed: 1.1ms preprocess, 126.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  868.5485
#
# 0: 480x640 3 Boulders, 3 craters, 141.1ms
# Speed: 1.5ms preprocess, 141.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  937.37823
#
# 0: 480x640 3 Boulders, 3 craters, 135.7ms
# Speed: 0.9ms preprocess, 135.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1036.301
#
# 0: 480x640 3 Boulders, 2 craters, 131.8ms
# Speed: 1.6ms preprocess, 131.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  860.9674
#
# 0: 480x640 3 Boulders, 2 craters, 146.7ms
# Speed: 1.0ms preprocess, 146.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  866.68634
#
# 0: 480x640 3 Boulders, 4 craters, 138.8ms
# Speed: 1.9ms preprocess, 138.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  928.1712
#
# 0: 480x640 3 Boulders, 1 crater, 136.3ms
# Speed: 1.0ms preprocess, 136.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  828.3224
#
# 0: 480x640 3 Boulders, 3 craters, 127.3ms
# Speed: 0.9ms preprocess, 127.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  920.6148
#
# 0: 480x640 4 Boulders, 1 crater, 124.8ms
# Speed: 1.3ms preprocess, 124.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  897.67474
#
# 0: 480x640 3 Boulders, 1 crater, 136.5ms
# Speed: 1.3ms preprocess, 136.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  996.4053
#
# 0: 480x640 6 Boulders, 2 craters, 139.8ms
# Speed: 1.0ms preprocess, 139.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  911.3966
#
# 0: 480x640 5 Boulders, 2 craters, 135.8ms
# Speed: 1.0ms preprocess, 135.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  916.794
#
# 0: 480x640 6 Boulders, 1 crater, 135.0ms
# Speed: 1.1ms preprocess, 135.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  870.2904
#
# 0: 480x640 5 Boulders, 1 crater, 126.3ms
# Speed: 1.0ms preprocess, 126.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  876.09784
#
# 0: 480x640 5 Boulders, 1 crater, 136.1ms
# Speed: 1.0ms preprocess, 136.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1425.6313
#
# 0: 480x640 2 Boulders, 8 craters, 131.3ms
# Speed: 1.1ms preprocess, 131.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1371.7179
#
# 0: 480x640 2 Boulders, 7 craters, 137.6ms
# Speed: 1.0ms preprocess, 137.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1634.6848
#
# 0: 480x640 2 Boulders, 10 craters, 137.4ms
# Speed: 1.3ms preprocess, 137.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1438.3756
#
# 0: 480x640 2 Boulders, 6 craters, 140.6ms
# Speed: 0.9ms preprocess, 140.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1472.4427
#
# 0: 480x640 2 Boulders, 6 craters, 138.8ms
# Speed: 1.1ms preprocess, 138.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1347.0886
#
# 0: 480x640 2 Boulders, 6 craters, 136.6ms
# Speed: 0.9ms preprocess, 136.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1512.5355
#
# 0: 480x640 2 Boulders, 8 craters, 134.7ms
# Speed: 0.9ms preprocess, 134.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1449.852
#
# 0: 480x640 3 Boulders, 4 craters, 141.4ms
# Speed: 1.6ms preprocess, 141.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1524.6215
#
# 0: 480x640 2 Boulders, 2 craters, 135.9ms
# Speed: 1.2ms preprocess, 135.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1534.9706
#
# 0: 480x640 2 Boulders, 3 craters, 126.8ms
# Speed: 1.1ms preprocess, 126.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1219.0333
#
# 0: 480x640 1 Boulder, 3 craters, 141.6ms
# Speed: 0.9ms preprocess, 141.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1214.7847
#
# 0: 480x640 1 Boulder, 3 craters, 141.9ms
# Speed: 1.1ms preprocess, 141.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1082.7048
#
# 0: 480x640 2 Boulders, 3 craters, 134.5ms
# Speed: 1.2ms preprocess, 134.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1081.4266
#
# 0: 480x640 2 Boulders, 4 craters, 132.1ms
# Speed: 1.0ms preprocess, 132.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1078.1504
#
# 0: 480x640 2 Boulders, 3 craters, 139.4ms
# Speed: 1.1ms preprocess, 139.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1099.1316
#
# 0: 480x640 3 Boulders, 4 craters, 174.7ms
# Speed: 1.0ms preprocess, 174.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1138.7955
#
# 0: 480x640 2 Boulders, 3 craters, 134.6ms
# Speed: 1.6ms preprocess, 134.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1128.183
#
# 0: 480x640 3 Boulders, 3 craters, 136.8ms
# Speed: 0.8ms preprocess, 136.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1059.5762
#
# 0: 480x640 2 Boulders, 4 craters, 139.1ms
# Speed: 1.2ms preprocess, 139.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1074.343
#
# 0: 480x640 2 Boulders, 5 craters, 138.9ms
# Speed: 1.1ms preprocess, 138.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1069.4763
#
# 0: 480x640 2 Boulders, 4 craters, 161.5ms
# Speed: 1.6ms preprocess, 161.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1049.974
#
# 0: 480x640 3 Boulders, 4 craters, 144.6ms
# Speed: 1.2ms preprocess, 144.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1104.8899
#
# 0: 480x640 5 Boulders, 3 craters, 136.7ms
# Speed: 1.0ms preprocess, 136.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1107.3225
#
# 0: 480x640 4 Boulders, 3 craters, 141.9ms
# Speed: 1.1ms preprocess, 141.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1084.7986
#
# 0: 480x640 9 Boulders, 4 craters, 139.4ms
# Speed: 1.0ms preprocess, 139.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1095.6445
#
# 0: 480x640 7 Boulders, 4 craters, 148.3ms
# Speed: 1.3ms preprocess, 148.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1074.1643
#
# 0: 480x640 7 Boulders, 5 craters, 136.6ms
# Speed: 1.4ms preprocess, 136.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  952.3316
#
# 0: 480x640 5 craters, 142.8ms
# Speed: 1.5ms preprocess, 142.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  945.05414
#
# 0: 480x640 5 craters, 128.6ms
# Speed: 1.3ms preprocess, 128.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  941.36224
#
# 0: 480x640 1 Boulder, 5 craters, 141.3ms
# Speed: 1.7ms preprocess, 141.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  917.4268
#
# 0: 480x640 5 craters, 135.5ms
# Speed: 0.9ms preprocess, 135.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  948.9242
#
# 0: 480x640 6 craters, 127.3ms
# Speed: 1.0ms preprocess, 127.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  939.00494
#
# 0: 480x640 5 craters, 141.1ms
# Speed: 1.1ms preprocess, 141.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  882.12897
#
# 0: 480x640 2 Boulders, 4 craters, 148.2ms
# Speed: 1.1ms preprocess, 148.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  878.8509
#
# 0: 480x640 2 Boulders, 128.0ms
# Speed: 1.0ms preprocess, 128.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  855.2139
#
# 0: 480x640 4 Boulders, 2 craters, 137.1ms
# Speed: 1.4ms preprocess, 137.1ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  962.5662
#
# 0: 480x640 2 Boulders, 1 crater, 136.2ms
# Speed: 1.1ms preprocess, 136.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1022.05585
#
# 0: 480x640 1 Boulder, 1 crater, 135.8ms
# Speed: 1.2ms preprocess, 135.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1163.1514
#
# 0: 480x640 2 Boulders, 5 craters, 144.3ms
# Speed: 1.3ms preprocess, 144.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1149.9286
#
# 0: 480x640 2 Boulders, 5 craters, 151.8ms
# Speed: 1.4ms preprocess, 151.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1182.6475
#
# 0: 480x640 3 Boulders, 7 craters, 145.8ms
# Speed: 1.1ms preprocess, 145.8ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1193.7296
#
# 0: 480x640 4 Boulders, 5 craters, 149.1ms
# Speed: 1.3ms preprocess, 149.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1155.9108
#
# 0: 480x640 3 Boulders, 5 craters, 139.3ms
# Speed: 1.6ms preprocess, 139.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1149.6003
#
# 0: 480x640 3 Boulders, 4 craters, 141.8ms
# Speed: 1.1ms preprocess, 141.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1154.7493
#
# 0: 480x640 2 Boulders, 4 craters, 137.4ms
# Speed: 1.1ms preprocess, 137.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1106.834
#
# 0: 480x640 3 Boulders, 6 craters, 144.4ms
# Speed: 1.2ms preprocess, 144.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1104.9612
#
# 0: 480x640 2 Boulders, 4 craters, 145.9ms
# Speed: 1.1ms preprocess, 145.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1090.0809
#
# 0: 480x640 2 Boulders, 4 craters, 140.2ms
# Speed: 1.1ms preprocess, 140.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1114.3264
#
# 0: 480x640 2 Boulders, 3 craters, 143.8ms
# Speed: 9.1ms preprocess, 143.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1101.5094
#
# 0: 480x640 2 Boulders, 5 craters, 145.2ms
# Speed: 1.0ms preprocess, 145.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1129.1287
#
# 0: 480x640 2 Boulders, 5 craters, 138.1ms
# Speed: 0.8ms preprocess, 138.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1176.0234
#
# 0: 480x640 2 Boulders, 4 craters, 149.2ms
# Speed: 1.0ms preprocess, 149.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1157.6161
#
# 0: 480x640 2 Boulders, 5 craters, 134.1ms
# Speed: 1.1ms preprocess, 134.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1174.7787
#
# 0: 480x640 2 Boulders, 5 craters, 133.3ms
# Speed: 2.4ms preprocess, 133.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1134.0988
#
# 0: 480x640 2 Boulders, 5 craters, 142.4ms
# Speed: 1.5ms preprocess, 142.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1162.1438
#
# 0: 480x640 3 Boulders, 5 craters, 128.6ms
# Speed: 1.5ms preprocess, 128.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1139.9402
#
# 0: 480x640 2 Boulders, 4 craters, 139.0ms
# Speed: 1.0ms preprocess, 139.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1149.1222
#
# 0: 480x640 2 Boulders, 6 craters, 130.1ms
# Speed: 1.1ms preprocess, 130.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1142.331
#
# 0: 480x640 2 Boulders, 4 craters, 152.3ms
# Speed: 1.0ms preprocess, 152.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1138.4216
#
# 0: 480x640 2 Boulders, 8 craters, 137.2ms
# Speed: 1.2ms preprocess, 137.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1135.1241
#
# 0: 480x640 2 Boulders, 5 craters, 149.4ms
# Speed: 1.6ms preprocess, 149.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1170.6045
#
# 0: 480x640 1 Boulder, 6 craters, 156.2ms
# Speed: 1.3ms preprocess, 156.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1212.6167
#
# 0: 480x640 1 Boulder, 6 craters, 145.5ms
# Speed: 1.1ms preprocess, 145.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1171.2019
#
# 0: 480x640 1 Boulder, 6 craters, 164.7ms
# Speed: 1.3ms preprocess, 164.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1207.1984
#
# 0: 480x640 1 Boulder, 5 craters, 154.6ms
# Speed: 1.2ms preprocess, 154.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1168.4768
#
# 0: 480x640 1 Boulder, 5 craters, 145.9ms
# Speed: 1.1ms preprocess, 145.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  1190.6351
#
# 0: 480x640 1 Boulder, 5 craters, 152.3ms
# Speed: 1.1ms preprocess, 152.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# MAX DEPTH:  927.51874
#
# 0: 480x640 3 craters, 151.4ms
# Speed: 1.0ms preprocess, 151.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
